# %% [markdown]
# # Assignment #02

# %% [markdown]
# ## Stereo Vision Disparity and Depth Map Calculation.
# ## Complete each question by implementing the required functions and code cells, following the instructions provided.

# %% [markdown]
# ## Importing Necessary Libraries

# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
from google.colab.patches import cv2_imshow

# Enable inline plotting for Google Colab
# %matplotlib inline

# %% [markdown]
# ## Disparity from Stereo Images

# %% [markdown]
# ### Define Camera Parameters

# %%
# Provided camera parameters
cam0 = np.array([[4152.073, 0, 1288.147],
                  [0, 4152.073, 973.571],
                  [0, 0, 1]])

cam1 = np.array([[4152.073, 0, 1501.231],
                  [0, 4152.073, 973.571],
                  [0, 0, 1]])

doffs = 213.084
baseline = 176.252
ndisp = 290
vmin = 33
vmax = 257
dyavg = 0.735
dymax = 1.694

# %% [markdown]
# ## Explain the significance of each camera parameter.
#
# ###   cam0 and cam1:
# ###   doffs:
# ###   baseline:
# ###   ndisp:
# ###   vmin:
# ###   vmax:
# ###   dyavg:
# ###   dymax:

# %% [markdown]
# ### Load Stereo Images and Display Them .

# %%
# Load the images in grayscale
left_image_path= './Images/im0.png'
right_image_path= './Images/im1.png'

left_image = cv2.imread(left_image_path, cv2.IMREAD_GRAYSCALE)
right_image = cv2.imread(right_image_path, cv2.IMREAD_GRAYSCALE)


# Display the left and right images
if left_image is None or right_image is None:
    print("Error loading images. Please check file paths.")
else:
    plt.figure(figsize=(10, 5))
    plt.subplot(1, 2, 1)
    plt.imshow(left_image, cmap='gray')
    plt.title("Left Image")
    plt.axis("off")

    plt.subplot(1, 2, 2)
    plt.imshow(right_image, cmap='gray')
    plt.title("Right Image")
    plt.axis("off")
    plt.show()

# %% [markdown]
# ### Describe the differences you observe in the left and right images (2 Points).

# %% [markdown]
# ### Configure and Apply Stereo Block Matching : Set up a stereo matcher and compute the disparity map between the left and right images using OpenCV's StereoSGBM method (3 Points).

# %%
def compute_and_display_disparity(left_image, right_image, window_size=5, min_disp=0, num_disp=64, vmax=None):
    """
    Computes and displays the disparity map from a pair of stereo images using StereoSGBM.

    Parameters:
    - left_image: numpy array, the left stereo image.
    - right_image: numpy array, the right stereo image.
    - window_size: int, size of the block used for matching (default: 5).
    - min_disp: int, minimum disparity (default: 0).
    - num_disp: int, number of disparities to consider (default: 64).
    - vmax: int or None, maximum disparity value for display scaling (default: None).

    Returns:
    - disparity_map: numpy array, the calculated disparity map.
    """
     # Code for StereoSGBM matcher will go here

    # Display disparity map
    plt.figure(figsize=(10, 5))
    plt.imshow(disparity_map, cmap='plasma', vmin=min_disp, vmax=vmax if vmax is not None else disparity_map.max())
    plt.colorbar(label="Disparity")
    plt.title("Disparity Map")
    plt.axis("off")
    plt.show()

# %% [markdown]
# ### What does the disparity map represent? How does it relate to depth perception? Write the Mathematical Relationship (2 Points)

# %%
#import numpy as np
import matplotlib.pyplot as plt

def compute_and_display_depth(disparity_map, focal_length, baseline, doffs=0.0):
    """
    Computes and displays the depth map from a disparity map.

    Parameters:
    - disparity_map: numpy array, the disparity map.
    - focal_length: float, the camera's focal length in pixels.
    - baseline: float, the baseline distance between the cameras in meters.
    - doffs: float, disparity offset (default: 0.0).

    Returns:
    - depth_map: numpy array, the calculated depth map.
    """

    # Avoid division by zero by replacing zero disparity with a small value
    disparity_map[disparity_map == 0] = 0.1

    # Calculate depth map using the formula
    # your code here

    # Display depth map
    plt.figure(figsize=(10, 5))
    plt.imshow(depth_map, cmap='viridis')
    plt.colorbar(label="Depth (mm)")
    plt.title("Depth Map")
    plt.axis("off")
    plt.show()

# %% [markdown]
# ## Tuning Parameters for Improved Disparity, Experiment with different parameters to see how they impact the disparity and depth maps (2 Pints).

# %%
# Modify parameters
window_size = ?     # Experiment with block size
num_disp = ?      # Number of disparities

# Re-create StereoSGBM with modified parameters

compute_and_display_disparity(left_image, right_image, window_size, num_disp)

# %% [markdown]
# ### Bonus Question: Limitations and Improvements. Analysis After observing the effects of parameter changes, answer the following questions:
#
# ### Q1 : How do changes in `window_size` and `num_disp` affect the disparity map?
# ### Q2 : What applications could benefit from depth maps generated from stereo images?
